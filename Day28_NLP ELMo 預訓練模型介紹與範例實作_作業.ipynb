# %% [markdown]
# # 作業 : 調整 ELMo 模型的不同訓練參數

# %% [markdown]
# # [作業目標]
# - 調整 ELMo 模型的不同參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [作業重點]
# - 調整 ELMo 模型的不同訓練參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [參數說明]
# - UNITS : LSTM 特徵維度，即每一筆訓練輸入單字的個數
# - N_LAYERS : LSTM 堆疊的層數
# - BATCH_SIZE : 訓練批次大小，即幾筆資料合併做一次倒傳遞
# - LEARNING_RATE : 學習速率，影響收斂的快慢，須配合 BATCH_SIZE 調整

# %% [markdown]
# # 程式說明
# - 程式採用 tensorflow2 / keras 寫作, 執行前請先安裝 tensorflow 2.0
# - 本程式執行時, 請將 utils.py 與執行檔放置於同一目錄下
# - 程式來源 : 莫煩Python-ELMo:一詞多義 https://mofanpy.com/tutorials/machine-learning/nlp/elmo/

# %%
# [Deep contextualized word representations](https://arxiv.org/pdf/1802.05365.pdf)
from tensorflow import keras
import tensorflow as tf
import utils    # this refers to utils.py in my [repo](https://github.com/MorvanZhou/NLP-Tutorials/)
import time
import os

class ELMo(keras.Model):
    def __init__(self, v_dim, emb_dim, units, n_layers, lr):
        super().__init__()
        self.n_layers = n_layers
        self.units = units

        # encoder
        self.word_embed = keras.layers.Embedding(
            input_dim=v_dim, output_dim=emb_dim,  # [n_vocab, emb_dim]
            embeddings_initializer=keras.initializers.RandomNormal(0., 0.001),
            mask_zero=True,
        )
        # forward lstm
        self.fs = [keras.layers.LSTM(units, return_sequences=True) for _ in range(n_layers)]
        self.f_logits = keras.layers.Dense(v_dim)
        # backward lstm
        self.bs = [keras.layers.LSTM(units, return_sequences=True, go_backwards=True) for _ in range(n_layers)]
        self.b_logits = keras.layers.Dense(v_dim)

        self.cross_entropy1 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.cross_entropy2 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.opt = keras.optimizers.Adam(lr)

    def call(self, seqs):
        embedded = self.word_embed(seqs)        # [n, step, dim]
        """
        0123    forward
        1234    forward predict
         1234   backward 
         0123   backward predict
        """
        mask = self.word_embed.compute_mask(seqs)
        fxs, bxs = [embedded[:, :-1]], [embedded[:, 1:]]
        for fl, bl in zip(self.fs, self.bs):
            fx = fl(
                fxs[-1], mask=mask[:, :-1], initial_state=fl.get_initial_state(fxs[-1])
            )           # [n, step-1, dim]
            bx = bl(
                bxs[-1], mask=mask[:, 1:], initial_state=bl.get_initial_state(bxs[-1])
            )  # [n, step-1, dim]
            fxs.append(fx)      # predict 1234
            bxs.append(tf.reverse(bx, axis=[1]))    # predict 0123
        return fxs, bxs

    def step(self, seqs):
        with tf.GradientTape() as tape:
            fxs, bxs = self.call(seqs)
            fo, bo = self.f_logits(fxs[-1]), self.b_logits(bxs[-1])
            loss = (self.cross_entropy1(seqs[:, 1:], fo) + self.cross_entropy2(seqs[:, :-1], bo))/2
        grads = tape.gradient(loss, self.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.trainable_variables))
        return loss, (fo, bo)

    def get_emb(self, seqs):
        fxs, bxs = self.call(seqs)
        xs = [tf.concat((f[:, :-1, :], b[:, 1:, :]), axis=2).numpy() for f, b in zip(fxs, bxs)]
        for x in xs:
            print("layers shape=", x.shape)
        return xs


def train(model, data, step):
    t0 = time.time()
    for t in range(step):
        seqs = data.sample(BATCH_SIZE)
        loss, (fo, bo) = model.step(seqs)
        if t % 80 == 0:
            fp = fo[0].numpy().argmax(axis=1)
            bp = bo[0].numpy().argmax(axis=1)
            t1 = time.time()
            print(
                "\n\nstep: ", t,
                "| time: %.2f" % (t1 - t0),
                "| loss: %.3f" % loss.numpy(),
                "\n| tgt: ", " ".join([data.i2v[i] for i in seqs[0] if i != data.pad_id]),
                "\n| f_prd: ", " ".join([data.i2v[i] for i in fp if i != data.pad_id]),
                "\n| b_prd: ", " ".join([data.i2v[i] for i in bp if i != data.pad_id]),
                )
            t0 = t1
    os.makedirs("./visual/models/elmo", exist_ok=True)
    model.save_weights("./visual/models/elmo/model.ckpt")


def export_w2v(model, data):
    model.load_weights("./visual/models/elmo/model.ckpt")
    emb = model.get_emb(data.sample(4))
    print(emb)


if __name__ == "__main__":
    utils.set_soft_gpu(True)
    UNITS = 256
    N_LAYERS = 2
    BATCH_SIZE = 16
    LEARNING_RATE = 2e-3
    d = utils.MRPCSingle("./MRPC", rows=2000)
    print("num word: ", d.num_word)
    m = ELMo(d.num_word, emb_dim=UNITS, units=UNITS, n_layers=N_LAYERS, lr=LEARNING_RATE)
    train(m, d, 10000)
    export_w2v(m, d)
# Out:
# num word:  12880
#
#
# step:  0 | time: 2.07 | loss: 9.463
# | tgt:  <GO> police arrested a <quote> potential suspect <quote> monday in the abduction of a <NUM>-year-old who was found safe after two days , the police chief said . <SEP>
# | f_prd:  acer acer mobility vern vern vern vern obtain outnumber outnumber outnumber outnumber hurting hurting trunk malice trunk atadero atadero 1980s expectancy expectancy expectancy idc idc supervisor supervisor supervisor supervisor supervisor supervisor supervisor supervisor supervisor supervisor supervisor supervisor
# | b_prd:  canon hornets canon anti-trust canon history spans transformed battalion battalion .... .... .... turquoise tool turquoise equal-weight gigabyte gigabyte winkenwerder winkenwerder winkenwerder winkenwerder banning lapel trade fraudulently rival
#
#
# step:  80 | time: 133.36 | loss: 6.524
# | tgt:  <GO> <quote> if it ain 't broke , don 't fix it , <quote> said senate minority leader tom daschle , a south dakota democrat . <SEP>
# | f_prd:
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  160 | time: 130.86 | loss: 6.353
# | tgt:  <GO> <quote> this sale is part of our efforts to simplify our foodservice products business and improve its cost structure , <quote> multifoods chairman and chief executive officer gary costley said . <SEP>
# | f_prd:  the the the the
# | b_prd:  , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , . . <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  240 | time: 130.36 | loss: 5.937
# | tgt:  <GO> in early u.s. trading , the euro < eur = > was down <NUM> percent to $ <NUM> , after rising to a four-month high of $ <NUM> . <SEP>
# | f_prd:  the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the . . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  320 | time: 135.48 | loss: 6.010
# | tgt:  <GO> at best , davydenko 's supporters were naively ignorant of tennis etiquette ; at worst , they cheated - yet went without penality from umpire lars graf . <SEP>
# | f_prd:  the the the the the the , ,
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , , . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  400 | time: 135.59 | loss: 5.749
# | tgt:  <GO> in taiwan , officials handed out free thermometers in an island-wide ``take-your-temperature ' ' campaign amid signs containment efforts were paying off . <SEP>
# | f_prd:  the the the the the the , , , , , . . . . . . . . . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  480 | time: 141.32 | loss: 5.875
# | tgt:  <GO> berkshire hathaway made profits of $ <NUM> billion in the first three months of this year alone , its best performance . <SEP>
# | f_prd:  the the the the the the the the , , , , , , . . . . . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the the the the the the the the the the . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  560 | time: 142.18 | loss: 5.652
# | tgt:  <GO> <quote> by its actions , the bush administration threatens to give a bad name to a just war , <quote> the connecticut democrat told a capitol hill news conference . <SEP>
# | f_prd:  the the the the , the , the , , the the , , , the the , . the the . . . . . . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , the the the , , the the <NUM> <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  640 | time: 135.52 | loss: 5.429
# | tgt:  <GO> capps ii will not use bank records , records indicating creditworthiness or medical records . <quote> <SEP>
# | f_prd:  the the , , the , , , the , , , the , . <SEP>
# | b_prd:  <GO> the the the the the the , the the the , the the <NUM> . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  720 | time: 131.56 | loss: 5.164
# | tgt:  <GO> the seizure of the money was confirmed by a us treasury official assigned to work with iraqi financial officers in baghdad in rebuilding the country 's banking and financial system . <SEP>
# | f_prd:  the the , the the , , , the <NUM> , , , , the , the <NUM> <NUM> , the . the . . . . . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , the , the the the , the , the the the , the , , the . . <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  800 | time: 147.28 | loss: 5.352
# | tgt:  <GO> he was taken to hammersmith hospital , where doctors regulated blair 's heart beat via electric shock in a procedure called <quote> cardio-version <quote> . <SEP>
# | f_prd:  the the , , the , , the the , <NUM> , <NUM> , , the , , the <NUM> . . the . the <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the , the the , the the , the the the , the <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  880 | time: 136.15 | loss: 5.468
# | tgt:  <GO> those that choose the handset option must have <NUM> percent of their customers using the technology by the end of <NUM> . <SEP>
# | f_prd:  the the the , the <NUM> , the <NUM> , , the <NUM> , the <NUM> <NUM> the <NUM> , the . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> the the <NUM> the the , <NUM> the the , the , <NUM> the the <NUM> the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  960 | time: 139.64 | loss: 4.951
# | tgt:  <GO> the survey that found it covered only a narrow slice of the sky . <SEP>
# | f_prd:  the the , the , , , <NUM> <NUM> , , the <NUM> . <SEP>
# | b_prd:  the the <NUM> the , , the the the the <NUM> the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1040 | time: 130.51 | loss: 4.805
# | tgt:  <GO> levin 's attorney , bo hitchcock , declined to comment friday . <SEP>
# | f_prd:  the , the <NUM> the <NUM> , the , the . . <SEP>
# | b_prd:  the <NUM> the <NUM> , the <NUM> the <NUM> the <NUM> said . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1120 | time: 127.68 | loss: 4.755
# | tgt:  <GO> he told the sun newspaper that mr. hussein 's daughters had british schools and hospitals in mind when they decided to ask for asylum . <SEP>
# | f_prd:  the said the <NUM> , , the <NUM> , <NUM> , <NUM> <NUM> , <NUM> , the , the , , the , the , <SEP>
# | b_prd:  , <NUM> the the , <NUM> , , <NUM> the <NUM> the the <NUM> the <NUM> the , , the <NUM> the <NUM> the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1200 | time: 122.14 | loss: 4.457
# | tgt:  <GO> a widely praised film of the same name was directed by wim wenders . <SEP>
# | f_prd:  the <NUM> , , , the <NUM> <NUM> , <NUM> , the <NUM> . <SEP>
# | b_prd:  <GO> <GO> <GO> the <NUM> the the the , the <NUM> the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1280 | time: 121.55 | loss: 4.648
# | tgt:  <GO> lendingtree matches borrowers via the internet with more than <NUM> mortgage brokers , banks and other lenders . <SEP>
# | f_prd:  the , , , the <NUM> <NUM> the <NUM> <NUM> , , . the . the <NUM> . <SEP>
# | b_prd:  <GO> <GO> the <GO> <GO> the <GO> <GO> , the the the <NUM> , <NUM> the the <NUM> .
#
#
# step:  1360 | time: 124.29 | loss: 4.537
# | tgt:  <GO> <quote> they have blocked all new bio-crops because of unfounded , unscientific fears , <quote> bush said . <SEP>
# | f_prd:  the the said the , the <NUM> , the the , the , . the the said . <SEP>
# | b_prd:  <GO> <GO> <GO> the the the the <NUM> <NUM> the <NUM> the the <NUM> , , <NUM> <NUM> .
#
#
# step:  1440 | time: 120.48 | loss: 4.720
# | tgt:  <GO> seven of the nine democratic presidential candidates were also scheduled to address the forum . <SEP>
# | f_prd:  the was the <NUM> <NUM> <NUM> <NUM> , a a to the the <NUM> . <SEP>
# | b_prd:  <GO> <GO> <GO> the the the the , , the <NUM> the to the said .
# step:  1520 | time: 119.69 | loss: 4.455
# | tgt:  <GO> commenting on the firing today , ms. novikova said that there was no standard weight for ballerinas but that ms. volochkova <quote> is bigger than others . <quote> <SEP>
# | f_prd:  the , the <NUM> <NUM> , the <NUM> , , the , not <NUM> <NUM> , the , the the <NUM> of the the <quote> <quote> said <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> the <GO> <GO> <GO> the <GO> <GO> <GO> <GO> <GO> the <GO> <GO> the , , , the , , the , the <NUM> . .
#
#
# step:  1600 | time: 118.65 | loss: 4.767
# | tgt:  <GO> the report was found last week tucked inside a training manual that belonged to hicks . <SEP>
# | f_prd:  the dow of a the <NUM> to a the <NUM> , <NUM> <NUM> , the . <SEP>
# | b_prd:  <GO> the , , , the , , , the the , the <NUM> the <NUM> .
#
#
# step:  1680 | time: 118.12 | loss: 4.702
# | tgt:  <GO> michael schiavo has argued that his wife never wanted to be kept alive artificially . <SEP>
# | f_prd:  the <NUM> , been the the <NUM> of been to the the to to . <SEP>
# | b_prd:  <GO> <GO> , , , , the the the , to and the the <NUM> .
#
#
# step:  1760 | time: 118.81 | loss: 4.447
# | tgt:  <GO> other contenders included general electric 's ge.n nbc , which submitted a letter of interest , a source familiar with the matter said . <SEP>
# | f_prd:  the <NUM> industrial the said <NUM> <NUM> the 's the said , than , the . the company . be the company . . <SEP>
# | b_prd:  the the <GO> <GO> <GO> <GO> the , <NUM> , the , the , the <NUM> , the , , in the <NUM> said .
#
#
# step:  1840 | time: 118.32 | loss: 3.790
# | tgt:  <GO> but odette is the first to form over the caribbean sea in december , the center said . <SEP>
# | f_prd:  the the , the <NUM> industrial the of the second , , the 's the bus , . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> the , the , , the the , to <NUM> , the <NUM> <NUM> .
#
#
# step:  1920 | time: 118.30 | loss: 3.909
# | tgt:  <GO> <quote> as a responsible leader we feel it necessary to make these changes because online chat services are increasingly being misused , <quote> microsoft told the bbc . <SEP>
# | f_prd:  the we the new , , not the , to be the companies , the , <NUM> , . . . . <quote> the said the statement . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , the <GO> the , the , the , to , the <NUM> , , , of the <NUM> .
#
#
# step:  2000 | time: 119.32 | loss: 3.721
# | tgt:  <GO> his wife said he was <quote> <NUM> percent behind george bush <quote> and looked forward to using his years of training in the war . <SEP>
# | f_prd:  the <NUM> 's the would not the percent to the <NUM> <NUM> the the the to the the states , the . the york . <SEP>
# | b_prd:  <GO> the , , , , to <NUM> , , , , , the , , , , <NUM> <NUM> the , in the <NUM> .
#
#
# step:  2080 | time: 118.36 | loss: 3.659
# | tgt:  <GO> massachusetts attorney general tom reilly did not let the judge 's penny-pinching get him down . <SEP>
# | f_prd:  the 's was <NUM> <NUM> of not be in <NUM> and transferring . . . . <SEP>
# | b_prd:  <GO> the <GO> <GO> the , , to of the , the to in , said .
#
#
# step:  2160 | time: 118.43 | loss: 3.669
# | tgt:  <GO> since march <NUM> , when the market 's major indexes were at their lowest levels since hitting multi-year lows in october , the nasdaq has barreled back <NUM> percent . <SEP>
# | f_prd:  the <NUM> <NUM> , the the euro , <NUM> <NUM> , been <NUM> lowest of , the multi-year , , the , the tech-laden of climbed . . . . <SEP>
# | b_prd:  <GO> the the <NUM> <GO> <GO> the <NUM> the the <NUM> , of the the , to to the , the <NUM> , the , , and $ <NUM> <NUM> .
#
#
# step:  2240 | time: 119.04 | loss: 3.835
# | tgt:  <GO> an episode is declared when the ozone reaches .20 parts per million parts of air for one hour . <SEP>
# | f_prd:  the barowitz was found the the new of been and , cent in . the . the . . <SEP>
# | b_prd:  <GO> the it the <GO> <GO> to , , the <NUM> <NUM> the <NUM> and , in the <NUM> .
#
#
# step:  2320 | time: 119.61 | loss: 3.610
# | tgt:  <GO> <quote> i 'm very proud of the citizens of this state , <quote> said gov. john baldacci , a casino foe . <SEP>
# | f_prd:  the the think not 't , the naacp , the masters of <quote> said the santangelo assure , <quote> world , . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> the , , the , , the <NUM> , , , , the <NUM> in the the <NUM> .
#
#
# step:  2400 | time: 118.96 | loss: 3.553
# | tgt:  <GO> the poll , conducted by krc communications research of newton , was taken wednesday and thursday . <SEP>
# | f_prd:  the company of the in the , , of the the the not in in comment . <SEP>
# | b_prd:  <GO> the <NUM> , , to the the , the <NUM> , and , , in <NUM> .
#
#
# step:  2480 | time: 119.66 | loss: 3.828
# | tgt:  <GO> a <NUM>-year-old mother of two is suspected of drowning her children in a bathtub before slashing her wrists in an unsuccessful suicide attempt , police said . <SEP>
# | f_prd:  the dow toy 's the <NUM> not <NUM> the , <NUM> , the dutch , the the <NUM> in the towel 'archiac , . <quote> said . <SEP>
# | b_prd:  <GO> the the <GO> the he <NUM> , to , and , , the , , to the , , the the the <NUM> , <NUM> <NUM> .
#
#
# step:  2560 | time: 118.91 | loss: 3.621
# | tgt:  <GO> three such vigilante-style attacks forced the hacker organizer , who identified himself only as <quote> eleonora [ <NUM> ] , <quote> to extend the contest until <NUM> p.m. est sunday . <SEP>
# | f_prd:  the 's vigilante-style <NUM> in the hacker organiser , which was , in as the eleonora67 as the and , where he extend the contest . the . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> the he <GO> the the <NUM> , , , in , , , , to , <NUM> , , to , the , to <NUM> , , said .
#
#
# step:  2640 | time: 118.14 | loss: 3.525
# | tgt:  <GO> it fell steadily until it dropped as low as $ <NUM> billion in <NUM> and rose gradually to $ <NUM> billion for fiscal <NUM> . <SEP>
# | f_prd:  the said <NUM> in the was the the as the <NUM> million , <NUM> percent <NUM> <NUM> . <NUM> <NUM> . . the <NUM> . <SEP>
# | b_prd:  <GO> <GO> the <NUM> , <NUM> <GO> , <GO> to $ <NUM> , $ , , , , to $ <NUM> , in in <NUM> .
#
#
# step:  2720 | time: 119.09 | loss: 3.126
# | tgt:  <GO> the airline said a similar discovery was made on the plane in houston . <SEP>
# | f_prd:  the dow has the governor of in a a the nation in the . <SEP>
# | b_prd:  <GO> the he <GO> the the , , <NUM> in a , in said .
#
#
# step:  2800 | time: 119.01 | loss: 3.482
# | tgt:  <GO> virtual pc , which microsoft acquired from connectix corp. in february , will not run on the g5 , the company said . <SEP>
# | f_prd:  the meester , the was 's by the in , the , said be be in the g5 , the company said . <SEP>
# | b_prd:  <GO> the <NUM> , , , <NUM> to was , in <NUM> , and to <NUM> in the <NUM> in the <NUM> <NUM> .
#
#
# step:  2880 | time: 119.22 | loss: 2.907
# | tgt:  <GO> they are located in grande cache , alta . , carrot river , sask . , chapleau , ont . , and aberdeen , wash . <SEP>
# | f_prd:  the said no in the absence , said , , carrot river 's sask . , chapleau , ont . , <SEP> aberdeen . wash . <SEP>
# | b_prd:  <GO> he <GO> <GO> <GO> <GO> <NUM> , <NUM> <NUM> , and <NUM> , <NUM> <NUM> , <NUM> , <NUM> percent , and <NUM> , <NUM> .
#
#
# step:  2960 | time: 118.81 | loss: 3.370
# | tgt:  <GO> rebels consolidated their grip on a troubled northeastern congolese town tuesday as residents identified at least <NUM> dead after a week of fighting . <SEP>
# | f_prd:  the sentiment from grip in the troubled northeastern congolese northeastern in , the from by least <NUM> , . the town . the . <SEP>
# | b_prd:  <GO> <GO> in a <NUM> , the , , to , , to , , to $ <NUM> , , a percent the <NUM> .
#
#
# step:  3040 | time: 118.73 | loss: 3.175
# | tgt:  <GO> magnarelli said racicot hated the iraqi regime and looked forward to using his long years of training in the war . <SEP>
# | f_prd:  the was the killed the dulles aid of the the to the the country confession from the in the past . <SEP>
# | b_prd:  <GO> he , was of the the <NUM> and be , and of the <NUM> <NUM> the <NUM> in the <NUM> .
#
#
# step:  3120 | time: 119.06 | loss: 2.994
# | tgt:  <GO> marcel desailly , the france captain and chelsea defender , believes the latter is true . <SEP>
# | f_prd:  the recruiters , the state and , the and in the the latter 's not . <SEP>
# | b_prd:  <GO> <GO> <NUM> , , , , the and percent , , the he and said .
# step:  3200 | time: 118.30 | loss: 3.043
# | tgt:  <GO> kodak expects earnings of <NUM> cents to <NUM> cents a share in the quarter . <SEP>
# | f_prd:  the , writer of the cents to $ cents a share . the new . <SEP>
# | b_prd:  <GO> , the <NUM> $ <NUM> , $ <NUM> , a , in a <NUM> .
#
#
# step:  3280 | time: 119.15 | loss: 3.164
# | tgt:  <GO> bob hope , master of the one-liner and americas favourite comedian , died with a smile on his face yesterday just months after celebrating his 100th birthday . <SEP>
# | f_prd:  the richter , the 's the one-liner of <NUM> management comedian , who from the smile , the wife in , the from the the 100th birthday . <SEP>
# | b_prd:  <GO> <GO> <NUM> a <NUM> of the , a and be <NUM> , , of to <NUM> of would , and <NUM> , , in a stock <NUM> .
#
#
# step:  3360 | time: 120.14 | loss: 2.896
# | tgt:  <GO> mr berlusconi is accused of bribing judges to influence a takeover battle in the 1980s involving sme , a state-owned food company . <SEP>
# | f_prd:  the schiavo was the of bribing judges to influence the takeover was in the atlantic of sme , <quote> state-owned state-owned . . <SEP>
# | b_prd:  <GO> <GO> he was <NUM> of was , to of a a <NUM> of the <NUM> and <NUM> in the the the <NUM> .
#
#
# step:  3440 | time: 121.35 | loss: 2.940
# | tgt:  <GO> winners will be announced in a june <NUM> ceremony broadcast on cbs from radio city music hall . <SEP>
# | f_prd:  the will get reached the the million-plus <NUM> , , were the . the 's . . . <SEP>
# | b_prd:  <GO> it to was , of the the the a <NUM> in <NUM> in the the stock <NUM> .
#
#
# step:  3520 | time: 127.13 | loss: 2.881
# | tgt:  <GO> instead , the high court said that drug makers did not adequately show why the plan should be prevented from taking effect . <SEP>
# | f_prd:  the of the expenditures , has the the makers have not adequately as why the shifts to be prevented with the effect . <SEP>
# | b_prd:  <GO> <NUM> <GO> the the , <GO> the , , has a be , , a , to be <NUM> , on <NUM> .
#
#
# step:  3600 | time: 131.77 | loss: 2.656
# | tgt:  <GO> ryan harvey , an outfielder from dunedin high school in florida , was selected with the sixth pick by the chicago cubs . <SEP>
# | f_prd:  the zulfiqar , the outfielder in dunedin colin school , <NUM> , said selected to the sixth pick in the region . . <SEP>
# | b_prd:  <GO> <GO> <NUM> <GO> the <NUM> of and was , of <NUM> , was , of the , , of to and <NUM> .
#
#
# step:  3680 | time: 131.95 | loss: 2.982
# | tgt:  <GO> even the pizza delivery took part , unwittingly delivering a leaflet with the missing girl 's picture during his run to cruz 's house . <SEP>
# | f_prd:  the saud new 's of a of delivering delivering a flier that the world time , picture supplies the effort , distract , largest , <SEP>
# | b_prd:  <GO> <GO> the 's , is <NUM> , , , a , of a the <NUM> the , on the , to <NUM> the <NUM> .
#
#
# step:  3760 | time: 133.85 | loss: 2.675
# | tgt:  <GO> <quote> sinners have long cherished the fantasy that william bennett , the virtue magnate , might be among our number , <quote> michael kinsely wrote . <SEP>
# | f_prd:  the we have a any the new that we winkenwerder , <quote> virtue magnate , <quote> be a the victory , <quote> said argus spokesman . <SEP>
# | b_prd:  <GO> <GO> a the , in the , was a <NUM> of the our . , to , of the . , <quote> , he said .
#
#
# step:  3840 | time: 128.67 | loss: 2.384
# | tgt:  <GO> that truck was spotted in the campbells creek area , fitting that description , morris said . <SEP>
# | f_prd:  the he is not in the fact creek contracted , which as description , and said . <SEP>
# | b_prd:  <GO> <GO> he was , of the a a <NUM> , , <quote> . , he <NUM> .
#
#
# step:  3920 | time: 125.74 | loss: 2.416
# | tgt:  <GO> during president bush 's trip to africa earlier this month , however , washington said it would support the increase . <SEP>
# | f_prd:  the the , , trip to sub-saharan , , week , the , will , in would pay the increase of <SEP>
# | b_prd:  <GO> the the poor a , to , on a <NUM> , <NUM> in , , , to in the said .
#
#
# step:  4000 | time: 122.85 | loss: 2.799
# | tgt:  <GO> last year , bush appointed him to the homeland security advisory council . <SEP>
# | f_prd:  the than , the appointed by in be united distributors advisory . . <SEP>
# | b_prd:  <GO> a <NUM> <GO> he to , in the 's new a said .
#
#
# step:  4080 | time: 128.20 | loss: 2.511
# | tgt:  <GO> at the pentagon , the department of defense 's inspector general has separately been asked to investigate how the telecom licences were awarded . <SEP>
# | f_prd:  the <NUM> first , kline dow of the and office , , been to to to investigate how the licences licences to awarded . <SEP>
# | b_prd:  <GO> <GO> the <NUM> <GO> the shares the poor the <GO> he , have and , to of in the the , stock said .
#
#
# step:  4160 | time: 128.64 | loss: 2.587
# | tgt:  <GO> the report was found oct. <NUM> , tucked inside an old three-ring binder not related to the investigation . <SEP>
# | f_prd:  the technology-laced was found in <NUM> , tucked inside the three-ring three-ring binder not related to the investigation . <SEP>
# | b_prd:  <GO> the he has the $ <NUM> , <NUM> , a a and and and according in the said .
#
#
# step:  4240 | time: 127.48 | loss: 2.574
# | tgt:  <GO> the judge ordered the unsealing yesterday at the request of several news agencies , including the seattle times , the associated press and the seattle post-intelligencer . <SEP>
# | f_prd:  the company is a unsealing in , the euro , the carolina of , including the seattle of of according company department . the seattle post-intelligencer . <SEP>
# | b_prd:  <GO> the also of the , , of the <NUM> of a and <NUM> , of in <NUM> <NUM> , to the , of the new said .
#
#
# step:  4320 | time: 126.85 | loss: 2.278
# | tgt:  <GO> some <NUM> customers were without power in the area , oklahoma gas and electric said . <SEP>
# | f_prd:  the <NUM> , were located an to the naval , oklahoma gas and gas , . <SEP>
# | b_prd:  <GO> the the , , our , of the <NUM> in the , and he said .
#
#
# step:  4400 | time: 126.05 | loss: 2.542
# | tgt:  <GO> the nasdaq composite index fell <NUM> , or <NUM> percent , to <NUM> following a loss of <NUM> the previous session . <SEP>
# | f_prd:  the technology-laced composite index < <NUM> points or <NUM> percent , to <NUM> , <NUM> highest of <NUM> . highest highest . <SEP>
# | b_prd:  <GO> technology-laced nasdaq composite index $ <NUM> , or <NUM> <NUM> , $ , on a percent to in the the <NUM> .
#
#
# step:  4480 | time: 126.07 | loss: 2.531
# | tgt:  <GO> he was joined by chief justice william h. rehnquist and justices antonin scalia and clarence thomas . <SEP>
# | f_prd:  the said arraigned in polls justice william h. rehnquist and justices antonin scalia and clarence thomas . <SEP>
# | b_prd:  <GO> he was <GO> and the has and and , and and and , and on <NUM> .
#
#
# step:  4560 | time: 127.29 | loss: 2.426
# | tgt:  <GO> also demonstrating box-office strength -- and getting seven tony nominations -- was a potent revival of eugene oneills family drama , long days journey into night . <quote> <SEP>
# | f_prd:  the who box-office victims _ the getting getting tony nominations , said not potent revival of the oneills , drama , <quote> days journey . the . <SEP> <SEP>
# | b_prd:  <quote> i and & . <GO> is of the 's . he of a , one to and the , <NUM> the <NUM> a <NUM> this longhorn . .
#
#
# step:  4640 | time: 125.95 | loss: 2.429
# | tgt:  <GO> the dollar was at <NUM> yen against the yen , flat on the session , and at <NUM> against the swiss franc , also flat . <SEP>
# | f_prd:  the technology-laced unemployment found <NUM> yen , the japanese , flat , the session , and the <NUM> , the swiss franc chf and flat . <SEP>
# | b_prd:  <GO> the <NUM> , or <NUM> <NUM> of <NUM> <NUM> was <NUM> of the percent , , $ <NUM> of the and percent and and <NUM> .
#
#
# step:  4720 | time: 126.56 | loss: 2.659
# | tgt:  <GO> the infineon case began in august <NUM> , when rambus accused infineon of patent infringement and infineon counter-sued rambus for breach of contract and fraud . <SEP>
# | f_prd:  the dow of was that least , , when the accused infineon of infineon infringement and infineon counter-sued rambus . breach of contract . breach . <SEP>
# | b_prd:  <GO> the the it <GO> in , <NUM> <GO> <GO> and , shares a , , and was and , in percent the , stock <NUM> .
# step:  4800 | time: 124.74 | loss: 2.414
# | tgt:  <GO> security forces stormed the building , but <NUM> hostages were killed along with the attackers . <SEP>
# | f_prd:  the press jurors the building after including the million in killed in with secretly <NUM> . <SEP>
# | b_prd:  nasdaq 's he of the <NUM> , the the , been , , on the said .
#
#
# step:  4880 | time: 124.74 | loss: 2.355
# | tgt:  <GO> mosel had been unable to present financial statements in time because of mergers among subsidiaries and a change of accountants , the company said yesterday . <SEP>
# | f_prd:  the was been unable to be de statements , velcade for his mergers a subsidiaries and the change network accountants , the company 's . . <SEP>
# | b_prd:  <GO> it have been expected to 's the <quote> the . part to was for , , the part in <NUM> , the <quote> year said .
#
#
# step:  4960 | time: 126.41 | loss: 2.322
# | tgt:  <GO> the eu 's agriculture representative in washington said eu ministers were invited but canceled because the union is wrapping up talks on agricultural reform . <SEP>
# | f_prd:  the company & decision malicious in the and the ministers were invited but canceled because the union is wrapping talks . with agricultural reform . <SEP>
# | b_prd:  <GO> the <NUM> 's a <GO> <GO> he <GO> nasdaq it was <GO> , <GO> <GO> the , and , on <NUM> on stock <NUM> .
#
#
# step:  5040 | time: 134.36 | loss: 2.391
# | tgt:  <GO> it went on : <quote> i picked prostitutes as my victims because i hated most prostitutes and i did not want to pay them for sex . <SEP>
# | f_prd:  the was to the the the think a : a victims because i hated the prostitutes , the did not want to be any . the . <SEP>
# | b_prd:  <GO> he said said , <quote> i been , of the said <quote> i and be , <quote> , and not , to for <NUM> 's said .
#
#
# step:  5120 | time: 124.81 | loss: 1.895
# | tgt:  <GO> the blue-chip dow jones industrial average .dji was down <NUM> points , or <NUM> percent , at <NUM> . <SEP>
# | f_prd:  the dow dow jones industrial average .dji slipped down <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  <GO> the the dow jones industrial index , was or <NUM> points , or <NUM> percent , to said .
#
#
# step:  5200 | time: 124.91 | loss: 1.918
# | tgt:  <GO> the dow jones industrial average ended the day down <NUM> at <NUM> , after advancing <NUM> wednesday . <SEP>
# | f_prd:  the dow jones industrial average .dji the <NUM> since <NUM> points <NUM> , or advancing <NUM> , . <SEP>
# | b_prd:  <GO> the dow jones industrial it , the was $ , $ percent <NUM> of to on said .
#
#
# step:  5280 | time: 129.26 | loss: 1.806
# | tgt:  <GO> shares of microsoft fell <NUM> cent to close at $ <NUM> on the nasdaq stock market . <SEP>
# | f_prd:  the of safeway 's <NUM> cents , $ at $ <NUM> , the nasdaq stock market . <SEP>
# | b_prd:  <GO> shares of index the per percent to , to $ <NUM> of the york stock said .
#
#
# step:  5360 | time: 129.16 | loss: 2.066
# | tgt:  <GO> san joaquin county sheriff 's deputies found <NUM>-year-old adan avalos of riverbank shot to death inside the suv . <SEP>
# | f_prd:  the architect county sheriff 's deputies dropped up adan avalos of riverbank shot by <NUM> . the suv . <SEP>
# | b_prd:  <GO> san nikia the poor the has a and and <NUM> of was , the <NUM> in the said .
#
#
# step:  5440 | time: 135.79 | loss: 1.936
# | tgt:  <GO> investigators were searching his home in muenster in the presence of his wife when news of his death came , prosecutor wolfgang schweer told the associated press . <SEP>
# | f_prd:  the said arrested the home in muenster in the presence of his wife , the of the wife where in prosecutor wolfgang schweer said the associated press . <SEP>
# | b_prd:  <GO> he was on the <NUM> in said in the one of a , the one of the <NUM> <NUM> the , united he of the the <NUM> .
#
#
# step:  5520 | time: 140.49 | loss: 1.984
# | tgt:  <GO> treatment guidelines , many written by medical specialty organizations , outline recommended approaches to many common ailments , ranging from painkillers and exercise for arthritis to surgery for breast cancer . <SEP>
# | f_prd:  the from , many written in medical-specialty specialty organizations , outline recommended approaches to be ailments ailments , ranging from painkillers and exercise . arthritis . surgery . surgery . . <SEP>
# | b_prd:  <GO> <GO> <NUM> , the , and stock stock <NUM> , , be , of inc two <NUM> , said for , and sense of according in available of clarence said .
#
#
# step:  5600 | time: 135.14 | loss: 2.061
# | tgt:  <GO> the girl turned up late sunday at a convenience store in east palo alto , about <NUM> miles from her home . <SEP>
# | f_prd:  the dow was up <NUM> sunday at the convenience store in east palo alto , about <NUM> miles from her home . <SEP>
# | b_prd:  <GO> the has was on on , on a a <NUM> its the al <NUM> , to <NUM> <NUM> of the <NUM> .
#
#
# step:  5680 | time: 141.83 | loss: 2.073
# | tgt:  <GO> on the upside , coca-cola co . ( nyse : ko - news - people ) reported higher profit for the quarter early on thursday , helped by european demand . <SEP>
# | f_prd:  the monday sidelines , the co for ( nyse : ko - news - news ) , higher profit , the quarter , on thursday . helped no european demand . <SEP>
# | b_prd:  <GO> <GO> the <NUM> <GO> nasdaq inc <NUM> the <NUM> , <NUM> ( <NUM> <NUM> <NUM> had the his responsibility in a said <NUM> on percent , said for on <NUM> .
#
#
# step:  5760 | time: 127.01 | loss: 2.186
# | tgt:  <GO> atlantic coast will continue its operations as a delta connections carrier . <SEP>
# | f_prd:  the and soared continue the operations in the delta connections carrier . <SEP>
# | b_prd:  the the it to for first , on the the the said .
#
#
# step:  5840 | time: 126.06 | loss: 2.043
# | tgt:  <GO> a key to that effort was the company 's introduction of a <NUM>-year , 100,000-mile warranty , meant to reassure buyers that they could trust the korean company . <SEP>
# | f_prd:  the dod utility the the <NUM> searching <NUM> , introduction of the final , 100,000-mile warranty , meant to reassure buyers , of could trust the korean company . <SEP>
# | b_prd:  <GO> the , <GO> the he , the <NUM> the some of a <NUM> , robert <NUM> , , to be said said , to in the the <NUM> .
#
#
# step:  5920 | time: 126.16 | loss: 1.991
# | tgt:  <GO> the american conservatives are clearly in the minority within the episcopal church . <SEP>
# | f_prd:  the dow recent were clearly incorrect the public of the shuttle church , <SEP>
# | b_prd:  <GO> the the , was said of the , of the the <NUM> .
#
#
# step:  6000 | time: 124.25 | loss: 1.685
# | tgt:  <GO> the technology-laced nasdaq composite index was down <NUM> points , or <NUM> percent , at <NUM> . <SEP>
# | f_prd:  the dow nasdaq composite index was down <NUM> points , or <NUM> percent , at <NUM> . <SEP>
# | b_prd:  <GO> the technology-laced nasdaq composite , was or <NUM> points , or <NUM> percent , to said .
#
#
# step:  6080 | time: 125.41 | loss: 2.070
# | tgt:  <GO> <quote> what they have done is a thinly veiled attempt to do an end run around the constitution , <quote> she said . <SEP>
# | f_prd:  the we we have done to the thinly veiled attempt to do a end run around the constitution , <quote> said said . <SEP>
# | b_prd:  , , <quote> we have it is a an an <quote> to in to the and in the said , , he said .
#
#
# step:  6160 | time: 126.04 | loss: 2.073
# | tgt:  <GO> shares of brocade closed at $ <NUM> , down $ <NUM> , or <NUM> percent . <SEP>
# | f_prd:  the of lendingtree closed at $ <NUM> , or <NUM> <NUM> , up <NUM> percent , <SEP>
# | b_prd:  <GO> shares of also , to $ <NUM> was to $ percent , to <NUM> said .
#
#
# step:  6240 | time: 127.15 | loss: 1.834
# | tgt:  <GO> car volume was down <NUM> percent , while light truck sales--which include vans , pickups and suvs--rose <NUM> percent . <SEP>
# | f_prd:  the who was moderate <NUM> percent , down light truck and include vans , pickups and suvs <NUM> percent . <SEP>
# | b_prd:  the and , was or <NUM> percent , and and stock an , <NUM> , , and to <NUM> said .
#
#
# step:  6320 | time: 151.90 | loss: 1.605
# | tgt:  <GO> the broader standard & poor 's <NUM> index .spx dropped <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | f_prd:  the dow standard & poor 's <NUM> index .spx dropped <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  <GO> the the standard & poor the <NUM> index , or <NUM> points , or <NUM> percent , to said .
# step:  6400 | time: 153.12 | loss: 1.978
# | tgt:  <GO> an average residential customer paying $ <NUM> a year for electricity could see a savings of $ <NUM> annually . <SEP>
# | f_prd:  the artist residential customer paying the <NUM> million year and electricity to be <NUM> savings of <NUM> <NUM> million . <SEP>
# | b_prd:  <GO> the index a to to to , a was on , to is a percent to $ <NUM> said .
#
#
# step:  6480 | time: 151.14 | loss: 1.836
# | tgt:  <GO> gerry kiely , a eu agriculture representative in washington , said eu ministers were invited but canceled because the union is closing talks on agricultural reform . <SEP>
# | f_prd:  the kiely , a eu agriculture representative in washington and said eu ministers were invited but canceled because the union is closing talks on agricultural reform . <SEP>
# | b_prd:  <GO> gerry <NUM> <GO> the 's agriculture <GO> in <NUM> he <GO> eu , were , , canceled said the , was on <NUM> on agricultural said .
#
#
# step:  6560 | time: 155.00 | loss: 1.636
# | tgt:  <GO> <quote> i think the longer the series goes , the more chance dirk has to play , <quote> nelson said . <SEP>
# | f_prd:  the i think it voluntary not citizens goes , <quote> <NUM>-year chance dirk has <NUM> play . <quote> nelson said . <SEP>
# | b_prd:  <GO> <quote> i in a in the two this , of the , , attempt to blacklist , <quote> he <NUM> .
#
#
# step:  6640 | time: 154.71 | loss: 1.932
# | tgt:  <GO> experts say legal challenges are rare before a bill becomes law . <SEP>
# | f_prd:  the were the challenges would rare the the bill becomes law . <SEP>
# | b_prd:  <GO> an that the , and said on a death the <NUM> .
#
#
# step:  6720 | time: 154.04 | loss: 1.856
# | tgt:  <GO> the infineon case began in august <NUM> , when rambus accused infineon of patent infringement and infineon counter-sued rambus for breach of contract and fraud . <SEP>
# | f_prd:  the broader of began in the is , when rambus accused infineon of patent infringement and infineon counter-sued rambus for breach of contract and fraud . <SEP>
# | b_prd:  <GO> the the it <GO> in , <NUM> <GO> of and and part of patent , and and elia sense for breach the , be <NUM> .
#
#
# step:  6800 | time: 156.66 | loss: 1.721
# | tgt:  <GO> florida legislators return today for a special session in which they 're expected to pass a compromise bill aimed at lowering doctors ' medical malpractice insurance rates . <SEP>
# | f_prd:  the 's reporters a that the special to , the i 're a to pass the compromise bill aimed out lowering doctors can news malpractice insurance rates . <SEP>
# | b_prd:  <GO> <NUM> to as recovering on a the said , <quote> we is expected to , a the , , at for , and economic 's morris <NUM> .
#
#
# step:  6880 | time: 153.21 | loss: 1.805
# | tgt:  <GO> the study also found that skin cancer nearly tripled in norway and sweden since the 1950s . <SEP>
# | f_prd:  the broader has features the buyers husband that <NUM> with norway and sweden of the 1950s . <SEP>
# | b_prd:  <GO> the he also said to for and and ritter in , testicular , in the said .
#
#
# step:  6960 | time: 157.80 | loss: 1.695
# | tgt:  <GO> lord of the rings director peter jackson and longtime companion fran walsh . <SEP>
# | f_prd:  the of the rings director peter jackson and longtime companion fran walsh . <SEP>
# | b_prd:  <GO> shares of the rings , of , and and and fran <NUM> .
#
#
# step:  7040 | time: 155.86 | loss: 1.646
# | tgt:  <GO> bryant was <quote> interviewed and was cooperative , <quote> said kim andree , a spokeswoman for the sheriff 's office . <SEP>
# | f_prd:  the had up interviewed and have cooperative rates but said kim andree , the spokeswoman for the sheriff 's office . <SEP>
# | b_prd:  <GO> he was <quote> , , was said , <quote> said marc dulmatin , a said of the sheriff 's said .
#
#
# step:  7120 | time: 156.43 | loss: 1.604
# | tgt:  <GO> now the rest is just mechanical , <quote> said allan hoffenblum , a republican consultant . <SEP>
# | f_prd:  the , rest said in mechanical , <quote> said allan hoffenblum , a republican consultant . <SEP>
# | b_prd:  , <GO> the there <quote> , said , <quote> said allan hoffenblum , a and said .
#
#
# step:  7200 | time: 155.97 | loss: 1.660
# | tgt:  <GO> agnew said pinellas began baiting when rabies cases <quote> went from zero to <NUM> <quote> in <NUM> . <SEP>
# | f_prd:  the said the began baiting if rabies cases <quote> went with zero to be percent options a . <SEP>
# | b_prd:  <GO> he <GO> he <quote> , , <NUM> , , <NUM> as , $ , <NUM> $ said .
#
#
# step:  7280 | time: 161.69 | loss: 1.523
# | tgt:  <GO> the shooting happened at <NUM> : <NUM> a.m. in the living room of the home the extended family shared on the city 's westside . <SEP>
# | f_prd:  the technology-laced victim so the percent <NUM> a.m. in the living room of the city that extended family shared on the city 's westside . <SEP>
# | b_prd:  <GO> the <NUM> <GO> $ <NUM> $ <NUM> <GO> in the the shares of a , the a <NUM> <NUM> to the keke 's said .
#
#
# step:  7360 | time: 128.13 | loss: 1.389
# | tgt:  <GO> it has a margin of error of plus or minus three to four percentage points . <SEP>
# | f_prd:  the was also margin of error of plus or minus <NUM> and <NUM> percentage points . <SEP>
# | b_prd:  <GO> he , a shares of percent , , or from , of <NUM> percentage said .
#
#
# step:  7440 | time: 125.05 | loss: 1.483
# | tgt:  <GO> commercial releases of the <NUM> kernel by major linux distributors still remain months away . <SEP>
# | f_prd:  the releases of the <NUM> kernel by major linux distributors still remain months away . <SEP>
# | b_prd:  <GO> the one of the a prisoner of and and and and <NUM> yuri <NUM> .
#
#
# step:  7520 | time: 145.62 | loss: 1.691
# | tgt:  <GO> world economic leaders hailed signs of a global revival on tuesday but agreed it had to be handled with care to prevent any setback . <SEP>
# | f_prd:  the of leaders hailed signs of the global revival saddam building that agreed at to to be handled with care to prevent any setback . <SEP>
# | b_prd:  the chief economic who , part of a potent went on said that said , scheduled to be charged and expected to for his said .
#
#
# step:  7600 | time: 142.84 | loss: 1.626
# | tgt:  <GO> a kayaker found dr. scribner 's body floating near the doctor 's houseboat in portage bay , where he was eating lunch when his wife , ethel , left for an appointment . <SEP>
# | f_prd:  the month found in michael 's eyes was on the euro , houseboat , portage bay , where he was eating lunch in it wife of ethel , <NUM> for a appointment . <SEP>
# | b_prd:  <GO> a was , , florida his that lying of a iraq a , 's portage <NUM> , said , was testicular , of his intranet , blondel he clubs with 's <NUM> .
#
#
# step:  7680 | time: 140.88 | loss: 1.662
# | tgt:  <GO> i urge congress to quickly resolve any differences and send me the final bill as soon as possible so that i can sign it into law . <quote> <SEP>
# | f_prd:  the can views has quickly resolve any differences , send me the final time as soon as possible so that he can sign it into <quote> . <quote> <SEP>
# | b_prd:  <quote> <quote> <GO> <quote> to to for 's <NUM> to quarantined of the the , be , as , <quote> <quote> i can sign journey the this . .
#
#
# step:  7760 | time: 148.99 | loss: 1.479
# | tgt:  <GO> a federal grand jury and the securities and exchange commission were looking into how the company allocated shares of initial public stock offerings . <SEP>
# | f_prd:  the kayaker magistrate jury and the united and exchange commission was looking into how the company allocated shares of initial public stock offerings . <SEP>
# | b_prd:  <GO> the a on <GO> <GO> the securities 's the , were was by , the baby allocated obstruction of the nasdaq stock said .
#
#
# step:  7840 | time: 141.85 | loss: 1.419
# | tgt:  <GO> amrozi did not reveal , and was not asked , the identity of his boss . <SEP>
# | f_prd:  the accused not reveal , but <NUM> not asked to and identity of his boss . <SEP>
# | b_prd:  , they did not <NUM> , , was not ueberroth of the share of his said .
#
#
# step:  7920 | time: 143.56 | loss: 1.541
# | tgt:  <GO> christina 's aunt , shelley riling , said the defense 's claims were preposterous . <SEP>
# | f_prd:  the 's aunt , shelley riling , said she lawsuit 's claims water preposterous . <SEP>
# | b_prd:  <GO> axcan 's index , michael . , said the father he , were said .
# step:  8000 | time: 145.23 | loss: 1.508
# | tgt:  <GO> when i talked to him last time , did i think it was the end-all ? <SEP>
# | f_prd:  the the think to the , week , he not think our was a end-all ? <SEP>
# | b_prd:  <GO> <quote> respectfully referring to said the ex-girlfriend , , i said he be the said .
#
#
# step:  8080 | time: 144.26 | loss: 1.400
# | tgt:  <GO> i stand <NUM> percent by it , and i think that our intelligence services gave us the correct intelligence and information at the time , <quote> blair said . <SEP>
# | f_prd:  the would the percent of the 's and i think our intelligence intelligence services gave the the correct intelligence services information at <quote> time . <quote> blair said . <SEP>
# | b_prd:  <quote> we about <NUM> weight pushed . , <quote> i rejection is 's 's i to on the material shuddered update aimed in the said , <quote> he said .
#
#
# step:  8160 | time: 145.77 | loss: 1.393
# | tgt:  <GO> <quote> it 's a new beginning as far as the courts , crown prosecution service and police are concerned , making the criminal justice system work better . <quote> <SEP>
# | f_prd:  the it 's amazing huge beginning as the as the courts , crown prosecution service and the are concerned , <quote> the criminal justice department . . . <quote> <SEP>
# | b_prd:  <GO> <quote> it is a new beginning as rejection of the slough , greek prosecution , , and is <quote> , of the the the to <quote> consumption . .
#
#
# step:  8240 | time: 160.33 | loss: 1.439
# | tgt:  <GO> a statement from the allied command said that the raid was part of <quote> the continued effort to eradicate baath party loyalists , paramilitary groups and other subversive elements . <quote> <SEP>
# | f_prd:  the month for the allied command said that the raid was <quote> of that a continued effort to eradicate baath party loyalists , paramilitary groups and a subversive elements . <quote> <SEP>
# | b_prd:  in a <GO> in the 's , <GO> <GO> the it is part : <quote> an the attempt to eradicate baath leak courts , paramilitary toys and 's subversive consumption . .
#
#
# step:  8320 | time: 157.69 | loss: 1.206
# | tgt:  <GO> <quote> the foodservice pie business does not fit our long-term growth strategy . <SEP>
# | f_prd:  the we whole pie business doesn not fit our long-term growth strategy . <SEP>
# | b_prd:  <GO> said the justice that that did not with 's economic public said .
#
#
# step:  8400 | time: 142.83 | loss: 1.296
# | tgt:  <GO> <quote> sanitation is poor ... there could be typhoid and cholera , <quote> he said . <SEP>
# | f_prd:  the i is poor , and were be typhoid and cholera , <quote> he said . <SEP>
# | b_prd:  <GO> <quote> sanitation h. <quote> <quote> it could be chemical and hormones , <quote> he said .
#
#
# step:  8480 | time: 141.81 | loss: 1.487
# | tgt:  <GO> <quote> it 's just too important to keeping crime down in the city to let it lapse , <quote> the mayor said of operation impact . <SEP>
# | f_prd:  the we 's obvious too important to keeping crime down , the united 's let a lapse , <quote> he mayor said of operation impact . <SEP>
# | b_prd:  <GO> <quote> it we , is taken to 's shut <NUM> in the expected not for it said , , the , <NUM> the 's said .
#
#
# step:  8560 | time: 128.49 | loss: 1.070
# | tgt:  <GO> durst , a millionaire , pleaded self-defense in the death of his neighbor morris black . <SEP>
# | f_prd:  the was poland millionaire , pleaded self-defense and the death of the neighbor morris black . <SEP>
# | b_prd:  <GO> qat , a woman they in muenster of the percent on his and web said .
#
#
# step:  8640 | time: 129.55 | loss: 1.399
# | tgt:  <GO> they also are reshaping the retail business relationship elsewhere , as companies take away ideas and practices that change how they do business in their own firms and with others . <SEP>
# | f_prd:  the said drafted reshaping the retail-business service relationship , , but companies take away ideas and practices a change how they could business . the own firms and could others . <SEP>
# | b_prd:  <GO> he they photographers of 's 's uninsured of percent , the to as merrill jharkhand and restaurants to on to to be categories of their electronics internally , and said .
#
#
# step:  8720 | time: 128.24 | loss: 1.429
# | tgt:  <GO> this year , peninsula health officials got the money to hire part-time water samplers and purchase testing equipment thanks to a $ <NUM> grant from the environmental protection agency . <SEP>
# | f_prd:  the change , local health management were a first to hire part-time water samplers and purchase testing equipment thanks to the prior <NUM> grant from morning environmental protection agency . <SEP>
# | b_prd:  <GO> this <NUM> , <GO> mr. it on in going to hired part-time water samplers and and secure is according of the about to percent on the environmental the said .
#
#
# step:  8800 | time: 129.04 | loss: 1.137
# | tgt:  <GO> about <NUM> percent of pakistan 's <NUM> million people are sunnis . <SEP>
# | f_prd:  the <NUM> people of pakistan 's <NUM> percent people are sunnis . <SEP>
# | b_prd:  <GO> , <NUM> index of company about <NUM> <NUM> , were <NUM> .
#
#
# step:  8880 | time: 129.39 | loss: 1.230
# | tgt:  <GO> police have arrested <NUM> people in connection with the murder of a young nigerian child whose headless and limbless torso was found floating in the river thames . <SEP>
# | f_prd:  the arrested been the people in connection with the murder of the murder nigerian child whose headless and limbless torso was found in in the river thames . <SEP>
# | b_prd:  <GO> we <GO> than <NUM> <GO> a charged of the some of the aid 's , her bound and and , was , said in the the said .
#
#
# step:  8960 | time: 127.93 | loss: 1.283
# | tgt:  <GO> an artist who painted a fake <quote> caution low flying planes <quote> sign on a building near ground zero said tuesday that he did not mean to offend anyone . <SEP>
# | f_prd:  the artist painted painted a fake <quote> caution low flying planes ' sign on to building near ground zero said the that he said not mean to offend anyone . <SEP>
# | b_prd:  <GO> an , artist in a as <quote> caution low flying i a talking on a building to <quote> <quote> on tiles , , did not devoted to on said .
#
#
# step:  9040 | time: 129.03 | loss: 1.366
# | tgt:  <GO> five alternate jurors also were selected , with a sixth alternate to be picked on friday . <SEP>
# | f_prd:  the alternate jurors were were selected , with a sixth alternate to be picked on friday . <SEP>
# | b_prd:  <GO> five alternate jurors , was percent compared of the moose plans could be <NUM> on <NUM> .
#
#
# step:  9120 | time: 128.13 | loss: 1.350
# | tgt:  <GO> we 're asphyxiating , ' ' ' said sam granato , chief of the kingsville police . <SEP>
# | f_prd:  the can asphyxiating , ' ' ' said sam granato , chief public the kingsville police . <SEP>
# | b_prd:  <quote> we 're woman , , , , the harold granato , part of the ' said .
#
#
# step:  9200 | time: 127.97 | loss: 1.242
# | tgt:  <GO> a downturn in services activity in march was the only break in what has been broad growth in services for the past <NUM> months . <SEP>
# | f_prd:  the month center the activity at march , the only break in a may been broad growth in services for the past <NUM> months . <SEP>
# | b_prd:  <GO> a <GO> 's grace <GO> in bergonzi was the rhodes break of , has been and <NUM> for half-staff in the in <NUM> said .
#
#
# step:  9280 | time: 128.02 | loss: 1.352
# | tgt:  <GO> at the united nations , the united states and britain are seeking backing for their agenda to hand over power to iraqis . <SEP>
# | f_prd:  the <NUM> economy nations , the united states and britain are seeking backing for the agenda to hand over power to iraqis . <SEP>
# | b_prd:  <GO> <GO> the united however <GO> the united <NUM> of they is to cumbersome with their agenda in hand without , to said .
#
#
# step:  9360 | time: 129.05 | loss: 1.256
# | tgt:  <GO> it was the <NUM>- yankees ' third straight defeat - their longest skid of the season . <SEP>
# | f_prd:  the is one first yankees ' third straight defeat - and longest skid of the season . <SEP>
# | b_prd:  <GO> it that the the the the a straight defeat for their longest part for the said .
#
#
# step:  9440 | time: 128.29 | loss: 1.266
# | tgt:  <GO> prince william county prosecutors told a judge yesterday they now want the trial of sniper suspect john allen muhammad moved out of the area . <SEP>
# | f_prd:  the william campbell prosecutors told a new service to have want to trial because sniper suspect john allen muhammad moved out of the area . <SEP>
# | b_prd:  <GO> e justice <GO> he said the said , would not with the because the sniper , and mohammad , partly end of the <NUM> .
# step:  9520 | time: 128.12 | loss: 1.107
# | tgt:  <GO> mel gibson is negotiating with newmarket films to distribute his embattled biblical epic <quote> the passion of christ <quote> in the united states . <SEP>
# | f_prd:  the gibson 's negotiating with newmarket films to distribute the embattled biblical epic <quote> the passion of christ united are the united states , <SEP>
# | b_prd:  <GO> jean-marie it is veteran with disc continue to with his embattled biblical , of the behalf of satisfaction strangled in the united said .
#
#
# step:  9600 | time: 133.24 | loss: 0.947
# | tgt:  <GO> brent crude for july delivery fell <NUM> cents to $ <NUM> a barrel on london 's international petroleum exchange . <SEP>
# | f_prd:  the crude for the delivery fell <NUM> cents to $ <NUM> a barrel on the 's international petroleum exchange . <SEP>
# | b_prd:  <GO> <GO> shares <GO> the shares rose <NUM> cents at $ as per barrel on google 's 's stock said .
#
#
# step:  9680 | time: 140.54 | loss: 1.320
# | tgt:  <GO> it will continue its regional service for delta air lines dal.n , atlantic coast said . <SEP>
# | f_prd:  the is be to regional service for delta and lines dal.n , atlantic coast said . <SEP>
# | b_prd:  <GO> it will pitching its our responsibility by chief an infrastructure dal.n the the he <NUM> .
#
#
# step:  9760 | time: 134.39 | loss: 1.220
# | tgt:  <GO> the redesigned finder also features search , coloured labels for customized organization of documents and projects and dynamic browsing of the network for mac , windows and unix file servers . <SEP>
# | f_prd:  the technology-laced finder who features search , coloured labels for customized organization , documents are projects , dynamic browsing of the network for mac , windows and unix file servers . <SEP>
# | b_prd:  <GO> the redesigned average also 's newisys to coloured pathway for the volumes of installations two smiled and dynamic browsing with financial posed for publish , neighbors and to capital said .
#
#
# step:  9840 | time: 121.72 | loss: 1.195
# | tgt:  <GO> the <NUM>-year bond us30yt = rr lost <NUM> / <NUM> , taking its yield to <NUM> percent from <NUM> percent . <SEP>
# | f_prd:  the dow bond us30yt = rr firmed <NUM> / <NUM> , taking its yield to <NUM> percent from <NUM> percent . <SEP>
# | b_prd:  <GO> the <NUM>-year bond us30yt = rr firmed <NUM> / <NUM> , taking its yield to <NUM> percent of <NUM> <NUM> .
#
#
# step:  9920 | time: 105.11 | loss: 1.117
# | tgt:  <GO> prosecutors reversed course friday and said they support moving the murder trial of sniper suspect john allen muhammad out of the washington suburbs . <SEP>
# | f_prd:  the said course friday with said that support moving the murder of of sniper suspect john allen muhammad . . the next suburbs . <SEP>
# | b_prd:  <GO> , watchdog on , , said and , of 's the city the sniper , john allen climb skid of the year said .
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# [array([[[-1.70044810e-01, -2.10045442e-01, -4.55885231e-01, ...,
#          -4.65977252e-01, -7.15101510e-02, -8.61553550e-02],
#         [-2.38464817e-01, -2.89971560e-01, -2.12734297e-01, ...,
#           2.48869270e-01, -3.20537835e-01,  1.69570968e-01],
#         [-1.28520340e-01, -3.06941569e-01,  8.36370662e-02, ...,
#           1.22021884e-01, -1.60448566e-01,  9.29693133e-02],
#         ...,
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04],
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04],
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04]],
#
#        [[-1.70044810e-01, -2.10045442e-01, -4.55885231e-01, ...,
#          -4.59773578e-02,  1.19681858e-01,  2.57752061e-01],
#         [ 2.67249614e-01, -1.03867762e-01, -2.77907401e-01, ...,
#          -1.08661406e-01,  5.31607449e-01, -2.02975795e-01],
#         [ 1.97978422e-01, -1.60993651e-01, -4.58453506e-01, ...,
#          -9.34935436e-02, -3.09384555e-01,  1.99571460e-01],
#         ...,
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04],
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04],
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04]],
#
#        [[-1.70044810e-01, -2.10045442e-01, -4.55885231e-01, ...,
#           3.80970240e-01,  2.39396140e-01,  2.11929649e-01],
#         [-6.08681664e-02, -2.67469823e-01, -1.25075832e-01, ...,
#           1.22021884e-01, -1.60448566e-01,  9.29693133e-02],
#         [-5.16922832e-01, -5.53975590e-02,  2.29594242e-02, ...,
#          -4.17107567e-02, -2.93245316e-02, -2.45267570e-01],
#         ...,
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04],
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04],
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04]],
#
#        [[-1.70044810e-01, -2.10045442e-01, -4.55885231e-01, ...,
#          -4.08597384e-03,  2.17802212e-01, -2.61008143e-02],
#         [ 1.68213975e-02,  4.22510765e-02, -1.16788141e-01, ...,
#           2.51678169e-01, -4.75061446e-01,  4.64448363e-01],
#         [ 2.46660560e-01,  2.42399611e-02,  1.07076988e-01, ...,
#           5.02166569e-01,  4.34769727e-02,  5.18228948e-01],
#         ...,
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04],
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04],
#         [ 5.79371175e-04, -2.30002654e-04,  4.77240537e-04, ...,
#           1.76608053e-04, -5.98595652e-04,  5.10696205e-04]]],
#       dtype=float32), array([[[-4.87755720e-08, -7.59942055e-01,  7.57410705e-01, ...,
#           7.61349916e-01,  9.15913582e-01,  9.98210073e-01],
#         [ 3.13880201e-03, -9.40550745e-01,  9.62497473e-01, ...,
#           7.13910758e-01,  9.52947617e-01,  9.93815422e-01],
#         [ 1.84954815e-02, -8.08068037e-01,  9.89521623e-01, ...,
#           6.74362302e-01,  3.84268165e-03,  2.13882595e-05],
#         ...,
#         [ 2.17334595e-10, -8.14413309e-01,  7.21573830e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.17334595e-10, -8.14413309e-01,  7.21573830e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.17334595e-10, -8.14413309e-01,  7.21573830e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-4.87755720e-08, -7.59942055e-01,  7.57410705e-01, ...,
#           7.59201648e-04,  9.99696255e-01,  8.51503015e-01],
#         [ 3.47284111e-03, -9.57282782e-01,  9.12594795e-01, ...,
#           2.85526663e-01,  9.93273914e-01,  9.53215837e-01],
#         [ 1.30624185e-05, -9.57662046e-01,  9.94853020e-01, ...,
#           7.36209154e-01,  7.75641441e-01,  2.20298767e-04],
#         ...,
#         [-3.04078457e-10, -8.66048217e-01,  5.29259443e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-3.04078457e-10, -8.66048217e-01,  5.29259443e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-3.04078457e-10, -8.66048217e-01,  5.29259443e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-4.87755720e-08, -7.59942055e-01,  7.57410705e-01, ...,
#           7.59245455e-01,  4.68126327e-01,  3.11613560e-01],
#         [ 9.73208770e-02, -9.63734090e-01,  9.43547428e-01, ...,
#           7.50293314e-01,  7.98722506e-01,  2.87285447e-03],
#         [ 1.94263230e-05, -7.61993527e-01,  9.79924977e-01, ...,
#           4.99094240e-02,  3.10553312e-02,  9.99982834e-01],
#         ...,
#         [ 9.85652948e-11, -8.51731777e-01,  6.39706850e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 9.85652948e-11, -8.51731777e-01,  6.39706850e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 9.85652948e-11, -8.51731777e-01,  6.39706850e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-4.87755720e-08, -7.59942055e-01,  7.57410705e-01, ...,
#           6.06437167e-03,  8.12802613e-02,  1.60959363e-02],
#         [ 7.46625960e-01, -9.62621570e-01,  4.46953885e-02, ...,
#           3.52067381e-01,  8.79437685e-01,  3.55778320e-05],
#         [ 2.16987431e-01, -9.91866350e-01,  7.75040917e-06, ...,
#           6.07435824e-03,  3.09468806e-01,  7.49192477e-05],
#         ...,
#         [-7.10762282e-10, -7.39085317e-01,  6.05195761e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-7.10762282e-10, -7.39085317e-01,  6.05195761e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-7.10762282e-10, -7.39085317e-01,  6.05195761e-04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#       dtype=float32), array([[[ 8.0382808e-05, -1.3903318e-02, -7.8191109e-02, ...,
#           7.2477792e-06, -9.8338199e-01,  9.7293937e-01],
#         [ 6.9268829e-08, -8.1068330e-02, -8.2603529e-02, ...,
#           8.5387558e-07, -9.9919963e-01,  9.9988753e-01],
#         [ 3.6865019e-06, -9.5803128e-04, -8.2308047e-02, ...,
#           2.6803655e-06, -6.8177110e-01,  8.0435455e-01],
#         ...,
#         [ 7.6134068e-01, -9.7406632e-01, -8.3005071e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 7.6134068e-01, -9.7406632e-01, -8.3005071e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 7.6134068e-01, -9.7406632e-01, -8.3005071e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 8.0382808e-05, -1.3903318e-02, -7.8191109e-02, ...,
#           8.1139106e-06, -7.7672052e-01,  1.2349677e-01],
#         [ 3.7940024e-04, -8.4574252e-02, -4.9139418e-02, ...,
#           4.1158360e-06, -1.6185045e-01,  9.5520830e-01],
#         [ 7.5888503e-01, -2.3711687e-01, -1.3408523e-04, ...,
#           8.1212456e-06, -1.0939658e-02,  9.9957919e-01],
#         ...,
#         [ 7.6219952e-01, -9.4337028e-01, -9.1926491e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 7.6219952e-01, -9.4337028e-01, -9.1926491e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 7.6219952e-01, -9.4337028e-01, -9.1926491e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 8.0382808e-05, -1.3903318e-02, -7.8191109e-02, ...,
#           5.2687153e-07, -9.7754669e-01,  9.9999738e-01],
#         [ 8.7007596e-05, -2.5419185e-03, -2.6443642e-02, ...,
#           1.5498036e-06, -9.8174882e-01,  5.5663079e-02],
#         [ 3.7899886e-06, -1.0640355e-02, -1.5833546e-05, ...,
#           9.0776957e-06, -2.9290724e-01,  7.2186929e-01],
#         ...,
#         [ 7.6187712e-01,  1.8943563e-01, -9.1176611e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 7.6187712e-01,  1.8943563e-01, -9.1176611e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 7.6187712e-01,  1.8943563e-01, -9.1176611e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 8.0382808e-05, -1.3903318e-02, -7.8191109e-02, ...,
#           4.9528098e-06, -9.9981773e-01,  9.5182538e-01],
#         [ 1.8388733e-02, -6.4942390e-03, -4.5505155e-02, ...,
#           1.6588353e-06, -9.1932821e-01,  9.9941385e-01],
#         [ 1.9499812e-02, -1.6788395e-05, -6.8183976e-01, ...,
#           1.0734101e-05, -8.1661659e-01,  2.6991585e-01],
#         ...,
#         [ 7.6151919e-01, -8.3629429e-01, -7.7863306e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 7.6151919e-01, -8.3629429e-01, -7.7863306e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 7.6151919e-01, -8.3629429e-01, -7.7863306e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]]], dtype=float32)]
